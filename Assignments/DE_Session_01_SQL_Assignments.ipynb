# %% [markdown]
# # 📘 SQL Practice Assignments
# ---
# This notebook contains two SQL practice assignments:
#
# 1. **Single Table SQL Core Functions**
# 2. **Two Tables SQL Joins & Analytics**

# %% [markdown]
# # 🧮 Assignment 1: SQL Core — Single Table Practice
#
# **Table:** `SALES_TRANSACTIONS`
# **Columns:** txn_id, txn_date, customer_id, product_id, region, qty, unit_price, payment_method, status
# **Derived column:** `gross_amount = qty * unit_price`
#
# ## 🧠 Objective
# Practice fundamental SQL operations using one table — filtering, grouping, aggregation, conditional logic, and window functions.
#
# ---
#
# ### Questions
#
# 1️⃣ Retrieve all transactions from the last 30 days, ordered by newest first.
# 2️⃣ Compute total gross revenue (sum of qty × unit_price).
# 3️⃣ List daily revenue for the past 14 days.
# 4️⃣ Find the top 5 regions by total revenue.
# 5️⃣ Show % share of each payment_method.
# 6️⃣ Exclude cancelled/refunded rows and calculate completed revenue.
# 7️⃣ Display transactions whose gross_amount > overall average.
# 8️⃣ Identify P90 outlier transactions.
# 9️⃣ Compute monthly revenue and month-over-month % change.
# 🔟 Return top 3 products per region by revenue (use ROW_NUMBER).
# 1️⃣1️⃣ Calculate refund rate = (refunded / completed) × 100 by region.
# 1️⃣2️⃣ Compare Card vs Non-Card revenue by month.
# 1️⃣3️⃣ Separate weekday vs weekend revenue for the last quarter.
# 1️⃣4️⃣ Compute 7-day rolling revenue per region (window frame).
# 1️⃣5️⃣ Show days since last purchase for each customer_id.
# 1️⃣6️⃣ Show first purchase month per customer_id.
# 1️⃣7️⃣ Display cumulative revenue trend by region over time.
# 1️⃣8️⃣ Implement pagination (page size = 20, ordered by txn_date DESC).
#
# ✅ *Covers:* SELECT, WHERE, GROUP BY, HAVING, ORDER BY, CASE, aggregate functions, date functions, window functions, subqueries, pagination.

# %% [markdown]
# # 🧩 Assignment 2: SQL Joins & Analytical Queries
#
# **Tables:**
# `CUSTOMERS(customer_id, customer_name, city, state, signup_date, is_active)`
# `ORDERS(order_id, customer_id, order_date, order_status, order_amount, channel)`
#
# ## 🎯 Objective
# Apply joins, subqueries, CTEs, grouping, window functions, and analytical logic across two tables.
#
# ---
#
# ### Questions
#
# 1️⃣ Compute total order amount per customer (name + total).
# 2️⃣ List customers with zero orders (using LEFT JOIN).
# 3️⃣ Show each customer’s first order date.
# 4️⃣ By month, classify customers as new or returning.
# 5️⃣ For active customers, compute average order value.
# 6️⃣ Produce channel mix (WEB/APP/STORE %) by state.
# 7️⃣ Identify the top city per state by revenue (ROW_NUMBER).
# 8️⃣ List customers who only placed cancelled orders.
# 9️⃣ Return active customers with no orders in last 90 days.
# 1️⃣0️⃣ Group customers by tenure (0-90, 91-180, 181-365, >365 days) and sum revenue.
# 1️⃣1️⃣ Compute monthly repeat rate (% customers with ≥ 2 orders).
# 1️⃣2️⃣ Provide order value percentiles (P50/P90/P95) by channel.
# 1️⃣3️⃣ For each signup month, sum revenue within first 60 days post-signup.
# 1️⃣4️⃣ List customers whose first order was > 60 days after signup.
# 1️⃣5️⃣ Identify cities with avg order ≥ overall city average and count their customers.
# 1️⃣6️⃣ Find top 5% customers by lifetime spend and their share of total revenue.
# 1️⃣7️⃣ List inactive customers whose lifetime spend > their cohort median (win-back list).
# 1️⃣8️⃣ a) Customers with ≥ 1 STORE order; b) Customers who never ordered via APP (anti join).
#
# ✅ *Covers:* INNER/LEFT JOIN, EXISTS/NOT EXISTS, GROUP BY, CASE, CTEs, analytic functions (RANK, PERCENTILE, LAG/LEAD), date calculations, and cohort analysis.
